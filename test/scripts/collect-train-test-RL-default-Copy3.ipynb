# %%
import matplotlib.pyplot as plt      
from mpl_toolkits import mplot3d
import os
import sys
import glob
import time
import shutil
import gym
from gym import error, spaces, utils
import numpy as np
import math
from pathlib import Path

# %%
import gym_fish

# %%
from gym_fish.envs.lib import pyflare as fl

# %%
Experiment_name = '90 degree servo control EMPIRICAL mass10 2_30 WP 1.0 wr 0.0 wa0.0'
Experiment_note = "change rotation reward"

# %%
os.chdir(Path(os.getcwd()+"/../").resolve())
print(os.getcwd())
# Out:
# /root/FishEnvPy/rl_test_new

# %% [markdown]
# ### Import Settings

# %%
cwd = os.getcwd()+"/"
data_folder =cwd+ 'py_data/'
json_folder =data_folder+'jsons/'
path_folder =json_folder+'paths/'
scripts_folder = cwd+'scripts/'

# %%
fluid_json = json_folder+'fluid_param_0.5.json'
rigid_json = json_folder+'rigids_2_30.json'
path_json = str(Path("./py_data/jsons/paths/line.json").resolve())
print(fluid_json)
print(rigid_json)
print(path_json)
# Out:
# /root/FishEnvPy/rl_test_new/py_data/jsons/fluid_param_0.5.json
# /root/FishEnvPy/rl_test_new/py_data/jsons/rigids_2_30.json
# /root/FishEnvPy/rl_test_new/py_data/jsons/paths/line.json

# %%
def plot_infos(infos,title,reward_fig_name):
    dd = {k:[] for k in infos[0].keys()}
    for info in infos:
        for k in info.keys():
            dd[k].append(info[k])
    plt.figure()
    for k in dd.keys():
        if k=='action_penality':
            plt.plot(np.arange(0,len(dd[k])),[kkk  for kkk in dd[k]],label=k)
        else:
            plt.plot(np.arange(0,len(dd[k])),dd[k],label=k)
    plt.legend()
    plt.title(title)
    plt.savefig(reward_fig_name)
    plt.show()

# %% [markdown]
# ### Output Settings

# %%
store_folder_name = time.strftime('%Y-%m-%d/',time.localtime(time.time()))+Experiment_name+'_'+time.strftime('%Y-%m-%d %H:%M/',time.localtime(time.time()))
imgs_folder_name = 'imgs/'
rl_data_folder_name = 'rl_data/'
rl_data_all_name='collected_o_a.npz'
network_folder_name = 'networks/'
store_folder = cwd+'output_data/'+store_folder_name
imgs_folder = store_folder+imgs_folder_name
rl_data_folder= store_folder+rl_data_folder_name
network_folder = store_folder+network_folder_name

if not os.path.exists(store_folder):
    os.makedirs(store_folder)
if not os.path.exists(imgs_folder):
    os.makedirs(imgs_folder)
if not os.path.exists(rl_data_folder):
    os.makedirs(rl_data_folder)
if not os.path.exists(network_folder):
    os.makedirs(network_folder)

# %% [markdown]
# ## Saving sources

# %%
save_sources = True
sources_folder_name = ['py_data','scripts']
if save_sources==True:
    for fn in sources_folder_name:
        shutil.copytree(cwd+fn,store_folder+'sources/'+fn)
with open(store_folder+'note.txt','w+') as f:
    f.write(time.strftime('%Y-%m-%d %H:%M\n',time.localtime(time.time())))
    f.write(Experiment_note)

# %% [markdown]
# ### RL_TRAINING Setup

# %%
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
from stable_baselines.common.vec_env import DummyVecEnv, VecCheckNan,VecNormalize
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## RL Begin

# %%
algo = 'PPO'
algofoler=algo+'/'
if not os.path.exists(network_folder+algofoler):
    os.makedirs(network_folder+algofoler)
if not os.path.exists(network_folder+algofoler+'imgs/'):
    os.makedirs(network_folder+algofoler+'imgs/')
if not os.path.exists(network_folder+algofoler+'imgs/trajs/'):
    os.makedirs(network_folder+algofoler+'imgs/trajs/')
if not os.path.exists(network_folder+algofoler+'imgs/rewards/'):
    os.makedirs(network_folder+algofoler+'imgs/rewards/')
if not os.path.exists(network_folder+algofoler+'models/'):
    os.makedirs(network_folder+algofoler+'models/')

# %%
from gym_fish.envs import FishEnv
env = make_vec_env(FishEnv, 
                   n_envs=1,
                   env_kwargs={
                       'gpuId':3,
                       'path_json':path_json,
                       'couple_mode':fl.COUPLE_MODE.EMPIRICAL,
                        'theta': 90,"frame_skip":100,
                       'fluid_json':fluid_json,"wp":1.0,"wr":0.0,"wa":0.0,
                       'rigid_json':rigid_json,
                       
                   })
# env = VecNormalize(env, norm_obs=False, norm_reward=False)
env_test=gym.make('fish-v0', 
                  gpuId=3,
                       path_json=path_json,
                        couple_mode= fl.COUPLE_MODE.EMPIRICAL,
                         theta = 90,frame_skip=100,
                       fluid_json=fluid_json,wp=1.0,wr=0.0,wa=0.0,
                       rigid_json=rigid_json,
                   )
# Out:
# 3
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]

# %%
policy_kwargs = None
model = PPO2(MlpPolicy, 
             env, 
            n_steps=64,
             verbose=1,
             tensorboard_log=network_folder+algofoler,
            )
# Out:
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
def evaluate_env(env_test,model,title,traj_fig_name,reward_fig_name,save=False,eval_trajs=3,render=False):
    
    obs = env_test.reset()
    dones = False
    infos = []
    reward = 0
    while not dones:
        action, _states = model.predict(obs, deterministic=True)
        if not save:
            obs, r, dones,info=env_test.step(action)
        else:
            obs, r, dones,info=env_test.stepSave(action,save_fluid=False)
        if render:
            env_test.render()
        reward=reward+r
        infos.append(info)
    plot_infos(infos,title=title,reward_fig_name=reward_fig_name)
    env_test.plot3d(title=title,fig_name = traj_fig_name)
    
    rewards= [reward]
    for i in range(eval_trajs-1):
        obs = env_test.reset()
        dones = False
        reward=0
        while not dones:
            action, _states = model.predict(obs, deterministic=True)
            obs, r, dones,_=env_test.step(action)
            reward=reward+r
        rewards.append(reward)
    print(np.mean(rewards))
    return np.mean(rewards)

# %% [markdown]
# ### RL Train

# %%
timesteps = int(1e6)
step = int(1e3)
length =int(timesteps/step) 
print(timesteps,step,length)
last_best_reward = -1e5
cur_steps = 0
# Out:
# 1000000 1000 1000

# %%
while cur_steps<timesteps:
    model.learn(total_timesteps=step, log_interval=1, reset_num_timesteps=False)
    cur_steps = cur_steps+step
    img_name =algo+ "_steps_{0}.png".format(cur_steps)
    model.save(network_folder+algofoler+'models/'+"_steps_{0}".format(cur_steps))
    rr = evaluate_env(env_test,model,title=img_name,traj_fig_name=network_folder+algofoler+'imgs/trajs/'+img_name,reward_fig_name=network_folder+algofoler+'imgs/rewards/'+img_name)
    if rr>last_best_reward:
        last_best_reward=rr
        model.save(network_folder+algofoler+'models/best')
# Out:
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1169: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# --------------------------------------
# | approxkl           | 0.00011187662 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 42            |
# | ep_reward_mean     | 2.7           |
# | explained_variance | 0.0941        |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.4187994     |
# | policy_loss        | -0.0036184895 |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.000132      |
# | total_timesteps    | 64            |
# | value_loss         | 0.47259003    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00012313551 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 46.5          |
# | ep_reward_mean     | 3.09          |
# | explained_variance | 0.148         |
# | fps                | 1             |
# | n_updates          | 2             |
# | policy_entropy     | 1.4198534     |
# | policy_loss        | -0.0025512385 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 40.7          |
# | total_timesteps    | 128           |
# | value_loss         | 0.14343974    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00018252712 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.2          |
# | ep_reward_mean     | 1.48          |
# | explained_variance | -0.0704       |
# | fps                | 1             |
# | n_updates          | 3             |
# | policy_entropy     | 1.4219513     |
# | policy_loss        | -0.0043821894 |
# | serial_timesteps   | 192           |
# | time_elapsed       | 76.6          |
# | total_timesteps    | 192           |
# | value_loss         | 0.6248359     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00010897685 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48            |
# | ep_reward_mean     | 2             |
# | explained_variance | 0.0269        |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.421784      |
# | policy_loss        | -0.0024254033 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 117           |
# | total_timesteps    | 256           |
# | value_loss         | 0.75275314    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 9.2556256e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 46.7          |
# | ep_reward_mean     | 2.14          |
# | explained_variance | 0.0968        |
# | fps                | 1             |
# | n_updates          | 5             |
# | policy_entropy     | 1.4212633     |
# | policy_loss        | -0.0029460506 |
# | serial_timesteps   | 320           |
# | time_elapsed       | 153           |
# | total_timesteps    | 320           |
# | value_loss         | 1.12733       |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00030089932 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.1          |
# | ep_reward_mean     | 0.422         |
# | explained_variance | -0.222        |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.4214435     |
# | policy_loss        | -0.003582135  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 190           |
# | total_timesteps    | 384           |
# | value_loss         | 0.5013872     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00056229526 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.6          |
# | ep_reward_mean     | 1.35          |
# | explained_variance | 0.0601        |
# | fps                | 1             |
# | n_updates          | 7             |
# | policy_entropy     | 1.4208076     |
# | policy_loss        | -0.005480039  |
# | serial_timesteps   | 448           |
# | time_elapsed       | 230           |
# | total_timesteps    | 448           |
# | value_loss         | 2.1596932     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0013510888 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 45.5         |
# | ep_reward_mean     | 0.663        |
# | explained_variance | -0.57        |
# | fps                | 1            |
# | n_updates          | 8            |
# | policy_entropy     | 1.4194738    |
# | policy_loss        | -0.01869315  |
# | serial_timesteps   | 512          |
# | time_elapsed       | 266          |
# | total_timesteps    | 512          |
# | value_loss         | 0.44398272   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0023816468 |
# | clipfrac           | 0.02734375   |
# | ep_len_mean        | 45.9         |
# | ep_reward_mean     | 0.903        |
# | explained_variance | -0.296       |
# | fps                | 1            |
# | n_updates          | 9            |
# | policy_entropy     | 1.418379     |
# | policy_loss        | -0.009348893 |
# | serial_timesteps   | 576          |
# | time_elapsed       | 308          |
# | total_timesteps    | 576          |
# | value_loss         | 0.6745255    |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0013516438 |
# | clipfrac           | 0.015625     |
# | ep_len_mean        | 45.9         |
# | ep_reward_mean     | 1.15         |
# | explained_variance | -0.444       |
# | fps                | 1            |
# | n_updates          | 10           |
# | policy_entropy     | 1.4167093    |
# | policy_loss        | -0.007731575 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 344          |
# | total_timesteps    | 640          |
# | value_loss         | 0.67858887   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00025176187 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 46.4          |
# | ep_reward_mean     | 1.84          |
# | explained_variance | -0.175        |
# | fps                | 1             |
# | n_updates          | 11            |
# | policy_entropy     | 1.415813      |
# | policy_loss        | -0.0020864983 |
# | serial_timesteps   | 704           |
# | time_elapsed       | 381           |
# | total_timesteps    | 704           |
# | value_loss         | 2.4732447     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0005632205  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 46.7          |
# | ep_reward_mean     | 2.25          |
# | explained_variance | -0.276        |
# | fps                | 1             |
# | n_updates          | 12            |
# | policy_entropy     | 1.4163151     |
# | policy_loss        | -0.0046273666 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 422           |
# | total_timesteps    | 768           |
# | value_loss         | 1.5380113     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0015535395 |
# | clipfrac           | 0.00390625   |
# | ep_len_mean        | 46.9         |
# | ep_reward_mean     | 2.67         |
# | explained_variance | 0.189        |
# | fps                | 1            |
# | n_updates          | 13           |
# | policy_entropy     | 1.416631     |
# | policy_loss        | -0.008272054 |
# | serial_timesteps   | 832          |
# | time_elapsed       | 458          |
# | total_timesteps    | 832          |
# | value_loss         | 1.0590315    |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 9.746131e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 47.1         |
# | ep_reward_mean     | 2.5          |
# | explained_variance | -0.477       |
# | fps                | 1            |
# | n_updates          | 14           |
# | policy_entropy     | 1.4166876    |
# | policy_loss        | 0.0010118391 |
# | serial_timesteps   | 896          |
# | time_elapsed       | 495          |
# | total_timesteps    | 896          |
# | value_loss         | 0.47936958   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0015421539  |
# | clipfrac           | 0.0078125     |
# | ep_len_mean        | 47            |
# | ep_reward_mean     | 2.71          |
# | explained_variance | -0.489        |
# | fps                | 1             |
# | n_updates          | 15            |
# | policy_entropy     | 1.4162786     |
# | policy_loss        | -0.0061722863 |
# | serial_timesteps   | 960           |
# | time_elapsed       | 536           |
# | total_timesteps    | 960           |
# | value_loss         | 1.7519096     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 0.8257283613767399
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00079037517 |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 47.1          |
# | ep_reward_mean     | 3.05          |
# | explained_variance | -0.312        |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.416619      |
# | policy_loss        | -0.0042206375 |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.000137      |
# | total_timesteps    | 1024          |
# | value_loss         | 2.1149929     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00016690238 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.3          |
# | ep_reward_mean     | 3.37          |
# | explained_variance | -0.427        |
# | fps                | 1             |
# | n_updates          | 2             |
# | policy_entropy     | 1.4186175     |
# | policy_loss        | -0.0010517105 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 36.4          |
# | total_timesteps    | 1088          |
# | value_loss         | 1.197512      |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0003128544  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.6          |
# | ep_reward_mean     | 3.57          |
# | explained_variance | -0.484        |
# | fps                | 1             |
# | n_updates          | 3             |
# | policy_entropy     | 1.419949      |
# | policy_loss        | -0.0021228297 |
# | serial_timesteps   | 192           |
# | time_elapsed       | 73.4          |
# | total_timesteps    | 1152          |
# | value_loss         | 0.79288596    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# ---------------------------------------
# | approxkl           | 8.217185e-05   |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 47.8           |
# | ep_reward_mean     | 3.78           |
# | explained_variance | -0.0797        |
# | fps                | 1              |
# | n_updates          | 4              |
# | policy_entropy     | 1.4210414      |
# | policy_loss        | -0.00018222071 |
# | serial_timesteps   | 256            |
# | time_elapsed       | 116            |
# | total_timesteps    | 1216           |
# | value_loss         | 1.3329551      |
# ---------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00011685997 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.9          |
# | ep_reward_mean     | 3.94          |
# | explained_variance | -0.264        |
# | fps                | 1             |
# | n_updates          | 5             |
# | policy_entropy     | 1.4212068     |
# | policy_loss        | 0.0014807731  |
# | serial_timesteps   | 320           |
# | time_elapsed       | 153           |
# | total_timesteps    | 1280          |
# | value_loss         | 0.82035387    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00046969397 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48            |
# | ep_reward_mean     | 3.97          |
# | explained_variance | -0.073        |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.4227391     |
# | policy_loss        | -0.0032035918 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 190           |
# | total_timesteps    | 1344          |
# | value_loss         | 1.6178075     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00028183335 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.2          |
# | ep_reward_mean     | 4.3           |
# | explained_variance | 0.0409        |
# | fps                | 1             |
# | n_updates          | 7             |
# | policy_entropy     | 1.4252745     |
# | policy_loss        | -0.0039064013 |
# | serial_timesteps   | 448           |
# | time_elapsed       | 227           |
# | total_timesteps    | 1408          |
# | value_loss         | 1.3287046     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00095557654 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.3          |
# | ep_reward_mean     | 4.53          |
# | explained_variance | 0.0168        |
# | fps                | 1             |
# | n_updates          | 8             |
# | policy_entropy     | 1.4272764     |
# | policy_loss        | -0.0015278142 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 268           |
# | total_timesteps    | 1472          |
# | value_loss         | 1.7057467     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0022737328 |
# | clipfrac           | 0.015625     |
# | ep_len_mean        | 48.3         |
# | ep_reward_mean     | 4.58         |
# | explained_variance | -0.207       |
# | fps                | 1            |
# | n_updates          | 9            |
# | policy_entropy     | 1.4272251    |
# | policy_loss        | -0.01165114  |
# | serial_timesteps   | 576          |
# | time_elapsed       | 304          |
# | total_timesteps    | 1536         |
# | value_loss         | 0.8746003    |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00060353626 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.4          |
# | ep_reward_mean     | 4.68          |
# | explained_variance | 0.00944       |
# | fps                | 1             |
# | n_updates          | 10            |
# | policy_entropy     | 1.4269606     |
# | policy_loss        | -0.0018478103 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 341           |
# | total_timesteps    | 1600          |
# | value_loss         | 1.7258933     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0009037491  |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 48.5          |
# | ep_reward_mean     | 4.67          |
# | explained_variance | 0.336         |
# | fps                | 1             |
# | n_updates          | 11            |
# | policy_entropy     | 1.4265417     |
# | policy_loss        | -0.0085459445 |
# | serial_timesteps   | 704           |
# | time_elapsed       | 382           |
# | total_timesteps    | 1664          |
# | value_loss         | 0.4114598     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# ---------------------------------------
# | approxkl           | 0.0022917865   |
# | clipfrac           | 0.0234375      |
# | ep_len_mean        | 48.6           |
# | ep_reward_mean     | 4.79           |
# | explained_variance | 0.406          |
# | fps                | 1              |
# | n_updates          | 12             |
# | policy_entropy     | 1.4261446      |
# | policy_loss        | -0.00078372704 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 420            |
# | total_timesteps    | 1728           |
# | value_loss         | 0.528006       |
# ---------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00086247636 |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 48.6          |
# | ep_reward_mean     | 4.81          |
# | explained_variance | 0.321         |
# | fps                | 1             |
# | n_updates          | 13            |
# | policy_entropy     | 1.4268793     |
# | policy_loss        | -0.007411074  |
# | serial_timesteps   | 832           |
# | time_elapsed       | 456           |
# | total_timesteps    | 1792          |
# | value_loss         | 1.2552649     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0009768265  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 5.14          |
# | explained_variance | 0.581         |
# | fps                | 1             |
# | n_updates          | 14            |
# | policy_entropy     | 1.4264894     |
# | policy_loss        | -0.0017935388 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 493           |
# | total_timesteps    | 1856          |
# | value_loss         | 1.0263665     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# ---------------------------------------
# | approxkl           | 0.000117430085 |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 48.8           |
# | ep_reward_mean     | 5.26           |
# | explained_variance | 0.49           |
# | fps                | 1              |
# | n_updates          | 15             |
# | policy_entropy     | 1.4270574      |
# | policy_loss        | -0.0033531017  |
# | serial_timesteps   | 960            |
# | time_elapsed       | 535            |
# | total_timesteps    | 1920           |
# | value_loss         | 0.55924207     |
# ---------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 0.8267582459789296
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0002840894  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 5.39          |
# | explained_variance | 0.647         |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.4280702     |
# | policy_loss        | -0.0010092806 |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.000157      |
# | total_timesteps    | 1984          |
# | value_loss         | 0.60006344    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0021692114 |
# | clipfrac           | 0.02734375   |
# | ep_len_mean        | 48.9         |
# | ep_reward_mean     | 5.55         |
# | explained_variance | 0.656        |
# | fps                | 1            |
# | n_updates          | 2            |
# | policy_entropy     | 1.4288415    |
# | policy_loss        | -0.011583553 |
# | serial_timesteps   | 128          |
# | time_elapsed       | 36.6         |
# | total_timesteps    | 2048         |
# | value_loss         | 0.75587356   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00053340016 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 5.84          |
# | explained_variance | 0.56          |
# | fps                | 1             |
# | n_updates          | 3             |
# | policy_entropy     | 1.4300928     |
# | policy_loss        | 0.00044008263 |
# | serial_timesteps   | 192           |
# | time_elapsed       | 72.7          |
# | total_timesteps    | 2112          |
# | value_loss         | 1.3378891     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0009014813 |
# | clipfrac           | 0.0078125    |
# | ep_len_mean        | 49.1         |
# | ep_reward_mean     | 5.92         |
# | explained_variance | 0.715        |
# | fps                | 1            |
# | n_updates          | 4            |
# | policy_entropy     | 1.431514     |
# | policy_loss        | -0.01260359  |
# | serial_timesteps   | 256          |
# | time_elapsed       | 113          |
# | total_timesteps    | 2176         |
# | value_loss         | 0.3875202    |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00053981994 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.1          |
# | ep_reward_mean     | 5.98          |
# | explained_variance | 0.554         |
# | fps                | 1             |
# | n_updates          | 5             |
# | policy_entropy     | 1.4317183     |
# | policy_loss        | 0.0061546126  |
# | serial_timesteps   | 320           |
# | time_elapsed       | 149           |
# | total_timesteps    | 2240          |
# | value_loss         | 0.6583195     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00074909383 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 5.99          |
# | explained_variance | -0.104        |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.430273      |
# | policy_loss        | -0.006623173  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 186           |
# | total_timesteps    | 2304          |
# | value_loss         | 3.3744297     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 3.0686315e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.6          |
# | ep_reward_mean     | 5.94          |
# | explained_variance | 0.204         |
# | fps                | 1             |
# | n_updates          | 7             |
# | policy_entropy     | 1.4284261     |
# | policy_loss        | 3.745174e-05  |
# | serial_timesteps   | 448           |
# | time_elapsed       | 225           |
# | total_timesteps    | 2368          |
# | value_loss         | 1.7952858     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00017062557 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.7          |
# | ep_reward_mean     | 6.05          |
# | explained_variance | 0.906         |
# | fps                | 1             |
# | n_updates          | 8             |
# | policy_entropy     | 1.4268867     |
# | policy_loss        | -0.00236808   |
# | serial_timesteps   | 512           |
# | time_elapsed       | 262           |
# | total_timesteps    | 2432          |
# | value_loss         | 0.20695016    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0010916102 |
# | clipfrac           | 0.0078125    |
# | ep_len_mean        | 48.5         |
# | ep_reward_mean     | 5.93         |
# | explained_variance | -0.0171      |
# | fps                | 1            |
# | n_updates          | 9            |
# | policy_entropy     | 1.4263737    |
# | policy_loss        | -0.008190749 |
# | serial_timesteps   | 576          |
# | time_elapsed       | 299          |
# | total_timesteps    | 2496         |
# | value_loss         | 4.104027     |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00013576211 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.5          |
# | ep_reward_mean     | 5.88          |
# | explained_variance | 0.335         |
# | fps                | 1             |
# | n_updates          | 10            |
# | policy_entropy     | 1.4259253     |
# | policy_loss        | 0.0005691238  |
# | serial_timesteps   | 640           |
# | time_elapsed       | 339           |
# | total_timesteps    | 2560          |
# | value_loss         | 1.4272072     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00018710089 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.4          |
# | ep_reward_mean     | 5.9           |
# | explained_variance | 0.672         |
# | fps                | 1             |
# | n_updates          | 11            |
# | policy_entropy     | 1.4264549     |
# | policy_loss        | -0.0017997783 |
# | serial_timesteps   | 704           |
# | time_elapsed       | 375           |
# | total_timesteps    | 2624          |
# | value_loss         | 1.1538143     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0011133589 |
# | clipfrac           | 0.015625     |
# | ep_len_mean        | 48.3         |
# | ep_reward_mean     | 5.9          |
# | explained_variance | 0.736        |
# | fps                | 1            |
# | n_updates          | 12           |
# | policy_entropy     | 1.427213     |
# | policy_loss        | -0.009109944 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 416          |
# | total_timesteps    | 2688         |
# | value_loss         | 0.48270875   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0018989498 |
# | clipfrac           | 0.01953125   |
# | ep_len_mean        | 48.4         |
# | ep_reward_mean     | 5.96         |
# | explained_variance | 0.884        |
# | fps                | 1            |
# | n_updates          | 13           |
# | policy_entropy     | 1.4274693    |
# | policy_loss        | -0.010269526 |
# | serial_timesteps   | 832          |
# | time_elapsed       | 453          |
# | total_timesteps    | 2752         |
# | value_loss         | 0.273615     |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0020707725 |
# | clipfrac           | 0.015625     |
# | ep_len_mean        | 48.4         |
# | ep_reward_mean     | 6.09         |
# | explained_variance | 0.93         |
# | fps                | 1            |
# | n_updates          | 14           |
# | policy_entropy     | 1.4281259    |
# | policy_loss        | 0.0015358655 |
# | serial_timesteps   | 896          |
# | time_elapsed       | 490          |
# | total_timesteps    | 2816         |
# | value_loss         | 0.13137223   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00059571525 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.5          |
# | ep_reward_mean     | 6.12          |
# | explained_variance | 0.916         |
# | fps                | 1             |
# | n_updates          | 15            |
# | policy_entropy     | 1.4277811     |
# | policy_loss        | -0.001789514  |
# | serial_timesteps   | 960           |
# | time_elapsed       | 530           |
# | total_timesteps    | 2880          |
# | value_loss         | 0.09894745    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 0.8907783251622021
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00018541745 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.5          |
# | ep_reward_mean     | 6.22          |
# | explained_variance | 0.716         |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.4277546     |
# | policy_loss        | 0.0008870475  |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.00014       |
# | total_timesteps    | 2944          |
# | value_loss         | 0.70615196    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0013175893 |
# | clipfrac           | 0.01171875   |
# | ep_len_mean        | 48.6         |
# | ep_reward_mean     | 6.28         |
# | explained_variance | 0.921        |
# | fps                | 1            |
# | n_updates          | 2            |
# | policy_entropy     | 1.428318     |
# | policy_loss        | -0.007168479 |
# | serial_timesteps   | 128          |
# | time_elapsed       | 36.9         |
# | total_timesteps    | 3008         |
# | value_loss         | 0.13904656   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# ------------------------------------
# | approxkl           | 0.00507089  |
# | clipfrac           | 0.0703125   |
# | ep_len_mean        | 48.7        |
# | ep_reward_mean     | 6.33        |
# | explained_variance | 0.897       |
# | fps                | 1           |
# | n_updates          | 3           |
# | policy_entropy     | 1.4284859   |
# | policy_loss        | -0.01580678 |
# | serial_timesteps   | 192         |
# | time_elapsed       | 73.6        |
# | total_timesteps    | 3072        |
# | value_loss         | 0.26895326  |
# ------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00066850585 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.7          |
# | ep_reward_mean     | 6.4           |
# | explained_variance | 0.942         |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.4288007     |
# | policy_loss        | -0.0012876494 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 113           |
# | total_timesteps    | 3136          |
# | value_loss         | 0.3191693     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0006325899 |
# | clipfrac           | 0.00390625   |
# | ep_len_mean        | 48.7         |
# | ep_reward_mean     | 6.49         |
# | explained_variance | 0.858        |
# | fps                | 1            |
# | n_updates          | 5            |
# | policy_entropy     | 1.428042     |
# | policy_loss        | -0.00355462  |
# | serial_timesteps   | 320          |
# | time_elapsed       | 150          |
# | total_timesteps    | 3200         |
# | value_loss         | 0.3768925    |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0013986649  |
# | clipfrac           | 0.01953125    |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 6.52          |
# | explained_variance | 0.777         |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.4258951     |
# | policy_loss        | -0.0007538481 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 187           |
# | total_timesteps    | 3264          |
# | value_loss         | 0.5985764     |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0005397691 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 48.7         |
# | ep_reward_mean     | 6.6          |
# | explained_variance | 0.721        |
# | fps                | 1            |
# | n_updates          | 7            |
# | policy_entropy     | 1.4247674    |
# | policy_loss        | -0.00323491  |
# | serial_timesteps   | 448          |
# | time_elapsed       | 224          |
# | total_timesteps    | 3328         |
# | value_loss         | 1.11539      |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 4.1021536e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.7          |
# | ep_reward_mean     | 6.68          |
# | explained_variance | 0.836         |
# | fps                | 1             |
# | n_updates          | 8             |
# | policy_entropy     | 1.4249841     |
# | policy_loss        | 0.00024167716 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 263           |
# | total_timesteps    | 3392          |
# | value_loss         | 0.42897624    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0004947206 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 48.8         |
# | ep_reward_mean     | 6.72         |
# | explained_variance | 0.898        |
# | fps                | 1            |
# | n_updates          | 9            |
# | policy_entropy     | 1.4254848    |
# | policy_loss        | -0.002843595 |
# | serial_timesteps   | 576          |
# | time_elapsed       | 300          |
# | total_timesteps    | 3456         |
# | value_loss         | 0.21818504   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0018947454  |
# | clipfrac           | 0.0234375     |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 6.8           |
# | explained_variance | 0.911         |
# | fps                | 1             |
# | n_updates          | 10            |
# | policy_entropy     | 1.4259439     |
# | policy_loss        | -0.0039863857 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 338           |
# | total_timesteps    | 3520          |
# | value_loss         | 0.25645086    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0010840496  |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 6.86          |
# | explained_variance | 0.935         |
# | fps                | 1             |
# | n_updates          | 11            |
# | policy_entropy     | 1.426548      |
# | policy_loss        | -0.0067960895 |
# | serial_timesteps   | 704           |
# | time_elapsed       | 377           |
# | total_timesteps    | 3584          |
# | value_loss         | 0.23821492    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00036336246 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 6.91          |
# | explained_variance | 0.975         |
# | fps                | 1             |
# | n_updates          | 12            |
# | policy_entropy     | 1.4261782     |
# | policy_loss        | -0.0004228428 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 413           |
# | total_timesteps    | 3648          |
# | value_loss         | 0.052836213   |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# -------------------------------------
# | approxkl           | 0.0020172296 |
# | clipfrac           | 0.01953125   |
# | ep_len_mean        | 48.9         |
# | ep_reward_mean     | 6.93         |
# | explained_variance | 0.869        |
# | fps                | 1            |
# | n_updates          | 13           |
# | policy_entropy     | 1.4260573    |
# | policy_loss        | -0.010916384 |
# | serial_timesteps   | 832          |
# | time_elapsed       | 450          |
# | total_timesteps    | 3712         |
# | value_loss         | 0.30196708   |
# -------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0004996985  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 7.04          |
# | explained_variance | 0.933         |
# | fps                | 1             |
# | n_updates          | 14            |
# | policy_entropy     | 1.4269843     |
# | policy_loss        | 0.00016656716 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 488           |
# | total_timesteps    | 3776          |
# | value_loss         | 0.28040087    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.0004955769  |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 7.03          |
# | explained_variance | 0.679         |
# | fps                | 1             |
# | n_updates          | 15            |
# | policy_entropy     | 1.4281831     |
# | policy_loss        | -0.0042909277 |
# | serial_timesteps   | 960           |
# | time_elapsed       | 528           |
# | total_timesteps    | 3840          |
# | value_loss         | 0.95521086    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 0.8907783251622021
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.004449857   |
# | clipfrac           | 0.04296875    |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 7.08          |
# | explained_variance | 0.934         |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.4297595     |
# | policy_loss        | -0.0053272126 |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.000139      |
# | total_timesteps    | 3904          |
# | value_loss         | 0.15594573    |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# ---------------------------------------
# | approxkl           | 0.00037041292  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 49             |
# | ep_reward_mean     | 7.13           |
# | explained_variance | 0.966          |
# | fps                | 1              |
# | n_updates          | 2              |
# | policy_entropy     | 1.4318751      |
# | policy_loss        | -0.00042674108 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 36.6           |
# | total_timesteps    | 3968           |
# | value_loss         | 0.08666667     |
# ---------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# ---------------------------------------
# | approxkl           | 6.571947e-05   |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 49             |
# | ep_reward_mean     | 7.17           |
# | explained_variance | 0.768          |
# | fps                | 1              |
# | n_updates          | 3              |
# | policy_entropy     | 1.4327427      |
# | policy_loss        | -3.6493642e-05 |
# | serial_timesteps   | 192            |
# | time_elapsed       | 74.4           |
# | total_timesteps    | 4032           |
# | value_loss         | 1.0441988      |
# ---------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]
# --------------------------------------
# | approxkl           | 0.00012440176 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 7.2           |
# | explained_variance | 0.972         |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.4325302     |
# | policy_loss        | 0.0011960859  |
# | serial_timesteps   | 256           |
# | time_elapsed       | 114           |
# | total_timesteps    | 4096          |
# | value_loss         | 0.051910605   |
# --------------------------------------
# 3
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [0.97686249 2.00028078 4.99999994] [6.123234e-17 0.000000e+00 1.000000e+00]

# %%
# !./clean_visdata.sh

# %%
model_test=PPO2.load(network_folder+algofoler+'models/best.zip')
evaluate_env(env_test,model_test,
             title="Best",
             traj_fig_name=network_folder+algofoler+'imgs/trajs/best.png',
             reward_fig_name=network_folder+algofoler+'imgs/rewards/best.png',
            render =False,
            save=True,eval_trajs=0
            )

# %%
# evaluate_env(env_test,model,
#              title="converge",
#              traj_fig_name=network_folder+algofoler+'imgs/trajs/converge.png',
#              reward_fig_name=network_folder+algofoler+'imgs/rewards/converge.png',
#             render =False,
#             save=True,eval_trajs=0
#             )
