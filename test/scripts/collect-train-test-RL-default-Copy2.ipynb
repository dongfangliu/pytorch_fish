# %%
import matplotlib.pyplot as plt      
from mpl_toolkits import mplot3d
import os
import sys
import glob
import time
import shutil
import gym
from gym import error, spaces, utils
import numpy as np
import math
from pathlib import Path

# %%
import gym_fish

# %%
from gym_fish.envs.lib import pyflare as fl

# %%
Experiment_name = '60 degree servo control TWO_WAY mass10 2_30 WP 1.0 wr 0.0 wa0.5'
Experiment_note = "change rotation reward"

# %%
os.chdir(Path(os.getcwd()+"/../").resolve())
print(os.getcwd())
# Out:
# /root/FishEnvPy/rl_test_new

# %% [markdown]
# ### Import Settings

# %%
cwd = os.getcwd()+"/"
data_folder =cwd+ 'py_data/'
json_folder =data_folder+'jsons/'
path_folder =json_folder+'paths/'
scripts_folder = cwd+'scripts/'

# %%
fluid_json = json_folder+'fluid_param_0.5.json'
rigid_json = json_folder+'rigids_2_30.json'
path_json = str(Path("./py_data/jsons/paths/line.json").resolve())
print(fluid_json)
print(rigid_json)
print(path_json)
# Out:
# /root/FishEnvPy/rl_test_new/py_data/jsons/fluid_param_0.5.json
# /root/FishEnvPy/rl_test_new/py_data/jsons/rigids_2_30.json
# /root/FishEnvPy/rl_test_new/py_data/jsons/paths/line.json

# %%
def plot_infos(infos,title,reward_fig_name):
    dd = {k:[] for k in infos[0].keys()}
    for info in infos:
        for k in info.keys():
            dd[k].append(info[k])
    plt.figure()
    for k in dd.keys():
        if k=='action_penality':
            plt.plot(np.arange(0,len(dd[k])),[kkk  for kkk in dd[k]],label=k)
        else:
            plt.plot(np.arange(0,len(dd[k])),dd[k],label=k)
    plt.legend()
    plt.title(title)
    plt.savefig(reward_fig_name)
    plt.show()

# %% [markdown]
# ### Output Settings

# %%
store_folder_name = time.strftime('%Y-%m-%d/',time.localtime(time.time()))+Experiment_name+'_'+time.strftime('%Y-%m-%d %H:%M/',time.localtime(time.time()))
imgs_folder_name = 'imgs/'
rl_data_folder_name = 'rl_data/'
rl_data_all_name='collected_o_a.npz'
network_folder_name = 'networks/'
store_folder = cwd+'output_data/'+store_folder_name
imgs_folder = store_folder+imgs_folder_name
rl_data_folder= store_folder+rl_data_folder_name
network_folder = store_folder+network_folder_name

if not os.path.exists(store_folder):
    os.makedirs(store_folder)
if not os.path.exists(imgs_folder):
    os.makedirs(imgs_folder)
if not os.path.exists(rl_data_folder):
    os.makedirs(rl_data_folder)
if not os.path.exists(network_folder):
    os.makedirs(network_folder)

# %% [markdown]
# ## Saving sources

# %%
save_sources = True
sources_folder_name = ['py_data','scripts']
if save_sources==True:
    for fn in sources_folder_name:
        shutil.copytree(cwd+fn,store_folder+'sources/'+fn)
with open(store_folder+'note.txt','w+') as f:
    f.write(time.strftime('%Y-%m-%d %H:%M\n',time.localtime(time.time())))
    f.write(Experiment_note)

# %% [markdown]
# ### RL_TRAINING Setup

# %%
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2
from stable_baselines.common.vec_env import DummyVecEnv, VecCheckNan,VecNormalize
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## RL Begin

# %%
algo = 'PPO'
algofoler=algo+'/'
if not os.path.exists(network_folder+algofoler):
    os.makedirs(network_folder+algofoler)
if not os.path.exists(network_folder+algofoler+'imgs/'):
    os.makedirs(network_folder+algofoler+'imgs/')
if not os.path.exists(network_folder+algofoler+'imgs/trajs/'):
    os.makedirs(network_folder+algofoler+'imgs/trajs/')
if not os.path.exists(network_folder+algofoler+'imgs/rewards/'):
    os.makedirs(network_folder+algofoler+'imgs/rewards/')
if not os.path.exists(network_folder+algofoler+'models/'):
    os.makedirs(network_folder+algofoler+'models/')

# %%
from gym_fish.envs import FishEnv
env = make_vec_env(FishEnv, 
                   n_envs=1,
                   env_kwargs={
                       'gpuId':2,
                       'path_json':path_json,
                       'couple_mode':fl.COUPLE_MODE.EMPIRICAL,
                        'theta': 60,"frame_skip":100,
                       'fluid_json':fluid_json,"wp":1.0,"wr":0.0,"wa":0.0,
                       'rigid_json':rigid_json,
                       
                   })
# env = VecNormalize(env, norm_obs=False, norm_reward=False)
env_test=gym.make('fish-v0', 
                  gpuId=2,
                       path_json=path_json,
                        couple_mode= fl.COUPLE_MODE.EMPIRICAL,
                         theta = 60,frame_skip=100,
                       fluid_json=fluid_json,wp=1.0,wr=0.0,wa=0.0,
                       rigid_json=rigid_json,
                   )
# Out:
# 2
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]

# %%
policy_kwargs = None
model = PPO2(MlpPolicy, 
             env, 
            n_steps=64,
             verbose=1,
             tensorboard_log=network_folder+algofoler,
            )
# Out:
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
def evaluate_env(env_test,model,title,traj_fig_name,reward_fig_name,save=False,eval_trajs=3,render=False):
    
    obs = env_test.reset()
    dones = False
    infos = []
    reward = 0
    while not dones:
        action, _states = model.predict(obs, deterministic=True)
        if not save:
            obs, r, dones,info=env_test.step(action)
        else:
            obs, r, dones,info=env_test.stepSave(action,save_fluid=True)
        if render:
            env_test.render()
        reward=reward+r
        infos.append(info)
    plot_infos(infos,title=title,reward_fig_name=reward_fig_name)
    env_test.plot3d(title=title,fig_name = traj_fig_name)
    
    rewards= [reward]
    for i in range(eval_trajs-1):
        obs = env_test.reset()
        dones = False
        reward=0
        while not dones:
            action, _states = model.predict(obs, deterministic=True)
            obs, r, dones,_=env_test.step(action)
            reward=reward+r
        rewards.append(reward)
    print(np.mean(rewards))
    return np.mean(rewards)

# %% [markdown]
# ### RL Train

# %%
timesteps = int(1e6)
step = int(1e3)
length =int(timesteps/step) 
print(timesteps,step,length)
last_best_reward = -1e5
cur_steps = 0
# Out:
# 1000000 1000 1000

# %%
while cur_steps<timesteps:
    model.learn(total_timesteps=step, log_interval=1, reset_num_timesteps=False)
    cur_steps = cur_steps+step
    img_name =algo+ "_steps_{0}.png".format(cur_steps)
    model.save(network_folder+algofoler+'models/'+"_steps_{0}".format(cur_steps))
    rr = evaluate_env(env_test,model,title=img_name,traj_fig_name=network_folder+algofoler+'imgs/trajs/'+img_name,reward_fig_name=network_folder+algofoler+'imgs/rewards/'+img_name)
    if rr>last_best_reward:
        last_best_reward=rr
        model.save(network_folder+algofoler+'models/best')
# Out:
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1169: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# WARNING:tensorflow:From /root/anaconda3/envs/sb/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# --------------------------------------
# | approxkl           | 0.00021462968 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 46            |
# | ep_reward_mean     | 6.46          |
# | explained_variance | -0.0293       |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.4205034     |
# | policy_loss        | -0.003187181  |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.00016       |
# | total_timesteps    | 64            |
# | value_loss         | 1.4375281     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00021413961 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.5          |
# | ep_reward_mean     | 6.56          |
# | explained_variance | -0.0935       |
# | fps                | 1             |
# | n_updates          | 2             |
# | policy_entropy     | 1.4234129     |
# | policy_loss        | -0.004738981  |
# | serial_timesteps   | 128           |
# | time_elapsed       | 41.9          |
# | total_timesteps    | 128           |
# | value_loss         | 0.633163      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# -------------------------------------
# | approxkl           | 0.0002029317 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 47.2         |
# | ep_reward_mean     | 6.09         |
# | explained_variance | 0.0122       |
# | fps                | 1            |
# | n_updates          | 3            |
# | policy_entropy     | 1.426059     |
# | policy_loss        | -0.003748604 |
# | serial_timesteps   | 192          |
# | time_elapsed       | 79.4         |
# | total_timesteps    | 192          |
# | value_loss         | 1.806217     |
# -------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 8.6508175e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48            |
# | ep_reward_mean     | 6.84          |
# | explained_variance | 0.000996      |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.4280688     |
# | policy_loss        | -0.0016197616 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 121           |
# | total_timesteps    | 256           |
# | value_loss         | 1.9737132     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00012350485 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 46.5          |
# | ep_reward_mean     | 6.13          |
# | explained_variance | 0.0658        |
# | fps                | 1             |
# | n_updates          | 5             |
# | policy_entropy     | 1.4283296     |
# | policy_loss        | -0.0010896992 |
# | serial_timesteps   | 320           |
# | time_elapsed       | 158           |
# | total_timesteps    | 320           |
# | value_loss         | 2.5571861     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00020220209 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47            |
# | ep_reward_mean     | 6.38          |
# | explained_variance | 0.038         |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.4282752     |
# | policy_loss        | -0.0028909864 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 195           |
# | total_timesteps    | 384           |
# | value_loss         | 0.44992468    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00024773646 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.4          |
# | ep_reward_mean     | 6.87          |
# | explained_variance | 0.00959       |
# | fps                | 1             |
# | n_updates          | 7             |
# | policy_entropy     | 1.4293661     |
# | policy_loss        | -0.0009920378 |
# | serial_timesteps   | 448           |
# | time_elapsed       | 236           |
# | total_timesteps    | 448           |
# | value_loss         | 1.8191329     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00013846799 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.8          |
# | ep_reward_mean     | 7.04          |
# | explained_variance | -0.166        |
# | fps                | 1             |
# | n_updates          | 8             |
# | policy_entropy     | 1.4303964     |
# | policy_loss        | -0.0018097945 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 272           |
# | total_timesteps    | 512           |
# | value_loss         | 1.106133      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 8.777189e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.3          |
# | ep_reward_mean     | 7.08          |
# | explained_variance | -0.111        |
# | fps                | 1             |
# | n_updates          | 9             |
# | policy_entropy     | 1.4306842     |
# | policy_loss        | -0.0022451594 |
# | serial_timesteps   | 576           |
# | time_elapsed       | 309           |
# | total_timesteps    | 576           |
# | value_loss         | 2.6079123     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00020899216 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.6          |
# | ep_reward_mean     | 7.43          |
# | explained_variance | -0.0631       |
# | fps                | 1             |
# | n_updates          | 10            |
# | policy_entropy     | 1.4310426     |
# | policy_loss        | -0.0053420374 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 350           |
# | total_timesteps    | 640           |
# | value_loss         | 2.2862957     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00047213447 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.9          |
# | ep_reward_mean     | 7.49          |
# | explained_variance | -0.197        |
# | fps                | 1             |
# | n_updates          | 11            |
# | policy_entropy     | 1.4302684     |
# | policy_loss        | -0.001505235  |
# | serial_timesteps   | 704           |
# | time_elapsed       | 387           |
# | total_timesteps    | 704           |
# | value_loss         | 0.556724      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.000203943   |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 47.6          |
# | ep_reward_mean     | 7.06          |
# | explained_variance | -0.0274       |
# | fps                | 1             |
# | n_updates          | 12            |
# | policy_entropy     | 1.4286704     |
# | policy_loss        | -0.0010127849 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 424           |
# | total_timesteps    | 768           |
# | value_loss         | 0.92182624    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ---------------------------------------
# | approxkl           | 2.371124e-05   |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 47.8           |
# | ep_reward_mean     | 7.41           |
# | explained_variance | -0.148         |
# | fps                | 1              |
# | n_updates          | 13             |
# | policy_entropy     | 1.4290006      |
# | policy_loss        | -0.00050564477 |
# | serial_timesteps   | 832            |
# | time_elapsed       | 465            |
# | total_timesteps    | 832            |
# | value_loss         | 2.3216205      |
# ---------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ---------------------------------------
# | approxkl           | 0.000107371605 |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 47.9           |
# | ep_reward_mean     | 7.6            |
# | explained_variance | -0.146         |
# | fps                | 1              |
# | n_updates          | 14             |
# | policy_entropy     | 1.4300014      |
# | policy_loss        | -0.00064848294 |
# | serial_timesteps   | 896            |
# | time_elapsed       | 501            |
# | total_timesteps    | 896            |
# | value_loss         | 2.3911717      |
# ---------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 3.871102e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.1          |
# | ep_reward_mean     | 7.83          |
# | explained_variance | -0.326        |
# | fps                | 1             |
# | n_updates          | 15            |
# | policy_entropy     | 1.4299015     |
# | policy_loss        | -0.0009976593 |
# | serial_timesteps   | 960           |
# | time_elapsed       | 538           |
# | total_timesteps    | 960           |
# | value_loss         | 2.035068      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 0.641807807299756
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 5.2536197e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.4          |
# | ep_reward_mean     | 8.11          |
# | explained_variance | -0.111        |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.4296178     |
# | policy_loss        | -0.0014145058 |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.000148      |
# | total_timesteps    | 1024          |
# | value_loss         | 2.275841      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00087577716 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.5          |
# | ep_reward_mean     | 8.4           |
# | explained_variance | -0.0249       |
# | fps                | 1             |
# | n_updates          | 2             |
# | policy_entropy     | 1.4296092     |
# | policy_loss        | -0.006727712  |
# | serial_timesteps   | 128           |
# | time_elapsed       | 39.6          |
# | total_timesteps    | 1088          |
# | value_loss         | 3.5669608     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0004689499  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48            |
# | ep_reward_mean     | 8.31          |
# | explained_variance | 0.141         |
# | fps                | 1             |
# | n_updates          | 3             |
# | policy_entropy     | 1.4293606     |
# | policy_loss        | -0.0026579616 |
# | serial_timesteps   | 192           |
# | time_elapsed       | 76.1          |
# | total_timesteps    | 1152          |
# | value_loss         | 2.211823      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0004150374  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.1          |
# | ep_reward_mean     | 8.47          |
# | explained_variance | -0.0423       |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.4296465     |
# | policy_loss        | -0.0032154948 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 117           |
# | total_timesteps    | 1216          |
# | value_loss         | 2.5121424     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# -------------------------------------
# | approxkl           | 3.372119e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 48.2         |
# | ep_reward_mean     | 8.62         |
# | explained_variance | 0.0511       |
# | fps                | 1            |
# | n_updates          | 5            |
# | policy_entropy     | 1.4290934    |
# | policy_loss        | 0.0006539121 |
# | serial_timesteps   | 320          |
# | time_elapsed       | 153          |
# | total_timesteps    | 1280         |
# | value_loss         | 1.7101626    |
# -------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0005269225  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.3          |
# | ep_reward_mean     | 8.66          |
# | explained_variance | 0.0535        |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.4277482     |
# | policy_loss        | -0.0036946712 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 190           |
# | total_timesteps    | 1344          |
# | value_loss         | 1.3755745     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0006020102  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.4          |
# | ep_reward_mean     | 8.63          |
# | explained_variance | 0.0436        |
# | fps                | 1             |
# | n_updates          | 7             |
# | policy_entropy     | 1.4260832     |
# | policy_loss        | -0.0053113834 |
# | serial_timesteps   | 448           |
# | time_elapsed       | 228           |
# | total_timesteps    | 1408          |
# | value_loss         | 2.4249315     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00053527177 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.5          |
# | ep_reward_mean     | 8.77          |
# | explained_variance | 0.291         |
# | fps                | 1             |
# | n_updates          | 8             |
# | policy_entropy     | 1.4252826     |
# | policy_loss        | -0.003008927  |
# | serial_timesteps   | 512           |
# | time_elapsed       | 268           |
# | total_timesteps    | 1472          |
# | value_loss         | 1.8710912     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ---------------------------------------
# | approxkl           | 0.0003347618   |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 48.6           |
# | ep_reward_mean     | 8.85           |
# | explained_variance | 0.265          |
# | fps                | 1              |
# | n_updates          | 9              |
# | policy_entropy     | 1.4244484      |
# | policy_loss        | -0.00087839784 |
# | serial_timesteps   | 576            |
# | time_elapsed       | 303            |
# | total_timesteps    | 1536           |
# | value_loss         | 1.730822       |
# ---------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00017284378 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.7          |
# | ep_reward_mean     | 8.96          |
# | explained_variance | 0.46          |
# | fps                | 1             |
# | n_updates          | 10            |
# | policy_entropy     | 1.4240029     |
# | policy_loss        | -0.0025572497 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 341           |
# | total_timesteps    | 1600          |
# | value_loss         | 1.8798773     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 2.8765586e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 9.15          |
# | explained_variance | 0.385         |
# | fps                | 1             |
# | n_updates          | 11            |
# | policy_entropy     | 1.4232991     |
# | policy_loss        | 0.00027171767 |
# | serial_timesteps   | 704           |
# | time_elapsed       | 378           |
# | total_timesteps    | 1664          |
# | value_loss         | 1.5912416     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ---------------------------------------
# | approxkl           | 6.3375286e-05  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 48.9           |
# | ep_reward_mean     | 9.18           |
# | explained_variance | 0.344          |
# | fps                | 1              |
# | n_updates          | 12             |
# | policy_entropy     | 1.4236199      |
# | policy_loss        | -0.00034528482 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 418            |
# | total_timesteps    | 1728           |
# | value_loss         | 1.363885       |
# ---------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0008974216  |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.17          |
# | explained_variance | 0.222         |
# | fps                | 1             |
# | n_updates          | 13            |
# | policy_entropy     | 1.4248676     |
# | policy_loss        | -0.0049253353 |
# | serial_timesteps   | 832           |
# | time_elapsed       | 454           |
# | total_timesteps    | 1792          |
# | value_loss         | 1.2269682     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# -------------------------------------
# | approxkl           | 0.000211897  |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 49           |
# | ep_reward_mean     | 9.22         |
# | explained_variance | 0.581        |
# | fps                | 1            |
# | n_updates          | 14           |
# | policy_entropy     | 1.4249915    |
# | policy_loss        | -0.001688764 |
# | serial_timesteps   | 896          |
# | time_elapsed       | 491          |
# | total_timesteps    | 1856         |
# | value_loss         | 1.0553846    |
# -------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00028502283 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.1          |
# | ep_reward_mean     | 9.27          |
# | explained_variance | 0.523         |
# | fps                | 1             |
# | n_updates          | 15            |
# | policy_entropy     | 1.4248607     |
# | policy_loss        | -0.0039974293 |
# | serial_timesteps   | 960           |
# | time_elapsed       | 528           |
# | total_timesteps    | 1920          |
# | value_loss         | 1.353912      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 0.6467606792883487
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# -------------------------------------
# | approxkl           | 0.0005382146 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 49.1         |
# | ep_reward_mean     | 9.3          |
# | explained_variance | 0.744        |
# | fps                | 1            |
# | n_updates          | 1            |
# | policy_entropy     | 1.4244599    |
# | policy_loss        | -0.001765091 |
# | serial_timesteps   | 64           |
# | time_elapsed       | 0.000171     |
# | total_timesteps    | 1984         |
# | value_loss         | 0.62107366   |
# -------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00068718684 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.2          |
# | ep_reward_mean     | 9.35          |
# | explained_variance | 0.771         |
# | fps                | 1             |
# | n_updates          | 2             |
# | policy_entropy     | 1.4264055     |
# | policy_loss        | -0.0041759717 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 36            |
# | total_timesteps    | 2048          |
# | value_loss         | 0.4975382     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0001348218  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.2          |
# | ep_reward_mean     | 9.37          |
# | explained_variance | 0.614         |
# | fps                | 1             |
# | n_updates          | 3             |
# | policy_entropy     | 1.4276959     |
# | policy_loss        | 0.00084862555 |
# | serial_timesteps   | 192           |
# | time_elapsed       | 72.5          |
# | total_timesteps    | 2112          |
# | value_loss         | 1.3662289     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00010373637 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.2          |
# | ep_reward_mean     | 9.44          |
# | explained_variance | 0.627         |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.427612      |
# | policy_loss        | -0.0010430648 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 110           |
# | total_timesteps    | 2176          |
# | value_loss         | 1.127948      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# -------------------------------------
# | approxkl           | 0.0006974874 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 49.1         |
# | ep_reward_mean     | 9.37         |
# | explained_variance | 0.548        |
# | fps                | 1            |
# | n_updates          | 5            |
# | policy_entropy     | 1.4266694    |
# | policy_loss        | -0.007520403 |
# | serial_timesteps   | 320          |
# | time_elapsed       | 150          |
# | total_timesteps    | 2240         |
# | value_loss         | 2.0211077    |
# -------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00027334283 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.2          |
# | ep_reward_mean     | 9.44          |
# | explained_variance | 0.932         |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.4255397     |
# | policy_loss        | 0.0025246874  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 188           |
# | total_timesteps    | 2304          |
# | value_loss         | 0.28267315    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0011129822  |
# | clipfrac           | 0.0078125     |
# | ep_len_mean        | 49.2          |
# | ep_reward_mean     | 9.55          |
# | explained_variance | 0.841         |
# | fps                | 1             |
# | n_updates          | 7             |
# | policy_entropy     | 1.4251156     |
# | policy_loss        | -0.0071004294 |
# | serial_timesteps   | 448           |
# | time_elapsed       | 225           |
# | total_timesteps    | 2368          |
# | value_loss         | 0.7781529     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00076655217 |
# | clipfrac           | 0.00390625    |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.46          |
# | explained_variance | 0.171         |
# | fps                | 1             |
# | n_updates          | 8             |
# | policy_entropy     | 1.4256707     |
# | policy_loss        | -0.004500513  |
# | serial_timesteps   | 512           |
# | time_elapsed       | 266           |
# | total_timesteps    | 2432          |
# | value_loss         | 3.030282      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00070886605 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.43          |
# | explained_variance | 0.595         |
# | fps                | 1             |
# | n_updates          | 9             |
# | policy_entropy     | 1.4263837     |
# | policy_loss        | -0.005360879  |
# | serial_timesteps   | 576           |
# | time_elapsed       | 302           |
# | total_timesteps    | 2496          |
# | value_loss         | 2.0454342     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00037441243 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.51          |
# | explained_variance | 0.963         |
# | fps                | 1             |
# | n_updates          | 10            |
# | policy_entropy     | 1.4256713     |
# | policy_loss        | 0.0012767034  |
# | serial_timesteps   | 640           |
# | time_elapsed       | 343           |
# | total_timesteps    | 2560          |
# | value_loss         | 0.47999257    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ------------------------------------
# | approxkl           | 0.001816037 |
# | clipfrac           | 0.015625    |
# | ep_len_mean        | 49          |
# | ep_reward_mean     | 9.55        |
# | explained_variance | 0.922       |
# | fps                | 1           |
# | n_updates          | 11          |
# | policy_entropy     | 1.425397    |
# | policy_loss        | -0.00698276 |
# | serial_timesteps   | 704         |
# | time_elapsed       | 380         |
# | total_timesteps    | 2624        |
# | value_loss         | 0.2044097   |
# ------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00080490933 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.63          |
# | explained_variance | 0.96          |
# | fps                | 1             |
# | n_updates          | 12            |
# | policy_entropy     | 1.426719      |
# | policy_loss        | -0.0015566384 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 417           |
# | total_timesteps    | 2688          |
# | value_loss         | 0.5380348     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# -------------------------------------
# | approxkl           | 0.0014703198 |
# | clipfrac           | 0.01171875   |
# | ep_len_mean        | 49.1         |
# | ep_reward_mean     | 9.76         |
# | explained_variance | 0.882        |
# | fps                | 1            |
# | n_updates          | 13           |
# | policy_entropy     | 1.4270327    |
# | policy_loss        | -0.002786165 |
# | serial_timesteps   | 832          |
# | time_elapsed       | 454          |
# | total_timesteps    | 2752         |
# | value_loss         | 0.45834988   |
# -------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 9.350175e-05  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.73          |
# | explained_variance | 0.594         |
# | fps                | 1             |
# | n_updates          | 14            |
# | policy_entropy     | 1.4282026     |
# | policy_loss        | 0.00040631217 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 495           |
# | total_timesteps    | 2816          |
# | value_loss         | 1.5085192     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# -------------------------------------
# | approxkl           | 4.758917e-05 |
# | clipfrac           | 0.0          |
# | ep_len_mean        | 49           |
# | ep_reward_mean     | 9.69         |
# | explained_variance | 0.369        |
# | fps                | 1            |
# | n_updates          | 15           |
# | policy_entropy     | 1.4291778    |
# | policy_loss        | 0.000584238  |
# | serial_timesteps   | 960          |
# | time_elapsed       | 532          |
# | total_timesteps    | 2880         |
# | value_loss         | 2.1179688    |
# -------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 0.6676083524803573
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ---------------------------------------
# | approxkl           | 2.8134787e-05  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 49             |
# | ep_reward_mean     | 9.7            |
# | explained_variance | 0.732          |
# | fps                | 1              |
# | n_updates          | 1              |
# | policy_entropy     | 1.4292213      |
# | policy_loss        | 0.000108845066 |
# | serial_timesteps   | 64             |
# | time_elapsed       | 0.000159       |
# | total_timesteps    | 2944           |
# | value_loss         | 1.1456492      |
# ---------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00030105884 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.69          |
# | explained_variance | 0.785         |
# | fps                | 1             |
# | n_updates          | 2             |
# | policy_entropy     | 1.428034      |
# | policy_loss        | -0.0025974864 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 41.5          |
# | total_timesteps    | 3008          |
# | value_loss         | 0.72548324    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00049488456 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.72          |
# | explained_variance | 0.919         |
# | fps                | 1             |
# | n_updates          | 3             |
# | policy_entropy     | 1.4287211     |
# | policy_loss        | -0.008710974  |
# | serial_timesteps   | 192           |
# | time_elapsed       | 78.4          |
# | total_timesteps    | 3072          |
# | value_loss         | 0.21207316    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00057163415 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.75          |
# | explained_variance | 0.644         |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.4282117     |
# | policy_loss        | 0.0022004088  |
# | serial_timesteps   | 256           |
# | time_elapsed       | 115           |
# | total_timesteps    | 3136          |
# | value_loss         | 1.3873597     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ---------------------------------------
# | approxkl           | 4.5372413e-05  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 49             |
# | ep_reward_mean     | 9.74           |
# | explained_variance | 0.851          |
# | fps                | 1              |
# | n_updates          | 5              |
# | policy_entropy     | 1.4285451      |
# | policy_loss        | -0.00079859793 |
# | serial_timesteps   | 320            |
# | time_elapsed       | 155            |
# | total_timesteps    | 3200           |
# | value_loss         | 0.6177375      |
# ---------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 5.2174975e-05 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.69          |
# | explained_variance | 0.435         |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.4300797     |
# | policy_loss        | 0.00037621567 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 192           |
# | total_timesteps    | 3264          |
# | value_loss         | 1.9554323     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0004758332  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.62          |
# | explained_variance | 0.769         |
# | fps                | 1             |
# | n_updates          | 7             |
# | policy_entropy     | 1.4307252     |
# | policy_loss        | -0.0045338413 |
# | serial_timesteps   | 448           |
# | time_elapsed       | 230           |
# | total_timesteps    | 3328          |
# | value_loss         | 1.065723      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00052171556 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.61          |
# | explained_variance | 0.87          |
# | fps                | 1             |
# | n_updates          | 8             |
# | policy_entropy     | 1.4307839     |
# | policy_loss        | -0.0012744796 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 270           |
# | total_timesteps    | 3392          |
# | value_loss         | 0.4991244     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00019782851 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.7          |
# | ep_reward_mean     | 9.46          |
# | explained_variance | 0.449         |
# | fps                | 1             |
# | n_updates          | 9             |
# | policy_entropy     | 1.4290017     |
# | policy_loss        | -0.0033080084 |
# | serial_timesteps   | 576           |
# | time_elapsed       | 307           |
# | total_timesteps    | 3456          |
# | value_loss         | 5.078377      |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00042120068 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.7          |
# | ep_reward_mean     | 9.48          |
# | explained_variance | 0.903         |
# | fps                | 1             |
# | n_updates          | 10            |
# | policy_entropy     | 1.4273179     |
# | policy_loss        | -0.0055431966 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 348           |
# | total_timesteps    | 3520          |
# | value_loss         | 0.3412273     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0004929817  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.7          |
# | ep_reward_mean     | 9.47          |
# | explained_variance | 0.897         |
# | fps                | 1             |
# | n_updates          | 11            |
# | policy_entropy     | 1.4266421     |
# | policy_loss        | -0.0029320037 |
# | serial_timesteps   | 704           |
# | time_elapsed       | 385           |
# | total_timesteps    | 3584          |
# | value_loss         | 0.32690817    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00026722313 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 9.5           |
# | explained_variance | 0.88          |
# | fps                | 1             |
# | n_updates          | 12            |
# | policy_entropy     | 1.4261724     |
# | policy_loss        | 0.00054372125 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 422           |
# | total_timesteps    | 3648          |
# | value_loss         | 0.53619826    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00013763596 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 9.58          |
# | explained_variance | 0.949         |
# | fps                | 1             |
# | n_updates          | 13            |
# | policy_entropy     | 1.4271374     |
# | policy_loss        | -0.0006355406 |
# | serial_timesteps   | 832           |
# | time_elapsed       | 459           |
# | total_timesteps    | 3712          |
# | value_loss         | 0.6506478     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0001034091  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.8          |
# | ep_reward_mean     | 9.54          |
# | explained_variance | 0.752         |
# | fps                | 1             |
# | n_updates          | 14            |
# | policy_entropy     | 1.4268501     |
# | policy_loss        | -0.0019894885 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 499           |
# | total_timesteps    | 3776          |
# | value_loss         | 0.7640337     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0005605068  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.55          |
# | explained_variance | 0.947         |
# | fps                | 1             |
# | n_updates          | 15            |
# | policy_entropy     | 1.4267334     |
# | policy_loss        | -0.0032878115 |
# | serial_timesteps   | 960           |
# | time_elapsed       | 537           |
# | total_timesteps    | 3840          |
# | value_loss         | 0.14518537    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 0.6972885785477203
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00016495706 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 48.9          |
# | ep_reward_mean     | 9.6           |
# | explained_variance | 0.788         |
# | fps                | 1             |
# | n_updates          | 1             |
# | policy_entropy     | 1.4270955     |
# | policy_loss        | 0.0006445295  |
# | serial_timesteps   | 64            |
# | time_elapsed       | 0.000141      |
# | total_timesteps    | 3904          |
# | value_loss         | 0.7618713     |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00018231466 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.6           |
# | explained_variance | 0.944         |
# | fps                | 1             |
# | n_updates          | 2             |
# | policy_entropy     | 1.426067      |
# | policy_loss        | -0.0016685054 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 37.2          |
# | total_timesteps    | 3968          |
# | value_loss         | 0.18138476    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# ---------------------------------------
# | approxkl           | 0.00012641164  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 49             |
# | ep_reward_mean     | 9.59           |
# | explained_variance | 0.901          |
# | fps                | 1              |
# | n_updates          | 3              |
# | policy_entropy     | 1.425894       |
# | policy_loss        | -0.00037234486 |
# | serial_timesteps   | 192            |
# | time_elapsed       | 77.7           |
# | total_timesteps    | 4032           |
# | value_loss         | 0.17183378     |
# ---------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00016795832 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.6           |
# | explained_variance | 0.914         |
# | fps                | 1             |
# | n_updates          | 4             |
# | policy_entropy     | 1.4271263     |
# | policy_loss        | -0.0016096376 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 115           |
# | total_timesteps    | 4096          |
# | value_loss         | 0.22076555    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.0001880807  |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49            |
# | ep_reward_mean     | 9.64          |
# | explained_variance | 0.923         |
# | fps                | 1             |
# | n_updates          | 5             |
# | policy_entropy     | 1.4285816     |
# | policy_loss        | -0.0016350416 |
# | serial_timesteps   | 320           |
# | time_elapsed       | 151           |
# | total_timesteps    | 4160          |
# | value_loss         | 0.46640623    |
# --------------------------------------
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# 2
# [0.97686249 2.00028078 2.99999994] [ 9.99980604e-01 -6.22825676e-03  2.04357705e-06] [1.97686249 2.00028078 4.73205075] [0.5       0.        0.8660254]
# --------------------------------------
# | approxkl           | 0.00037243453 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 49.1          |
# | ep_reward_mean     | 9.66          |
# | explained_variance | 0.921         |
# | fps                | 1             |
# | n_updates          | 6             |
# | policy_entropy     | 1.429714      |
# | policy_loss        | -0.0033195403 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 187           |
# | total_timesteps    | 4224          |
# | value_loss         | 0.3025251     |
# --------------------------------------

# %%
# !./clean_visdata.sh

# %%
model_test=PPO2.load(network_folder+algofoler+'models/best.zip')
evaluate_env(env_test,model_test,
             title="Best",
             traj_fig_name=network_folder+algofoler+'imgs/trajs/best.png',
             reward_fig_name=network_folder+algofoler+'imgs/rewards/best.png',
            render =False,
            save=True,eval_trajs=0
            )

# %%
# evaluate_env(env_test,model,
#              title="converge",
#              traj_fig_name=network_folder+algofoler+'imgs/trajs/converge.png',
#              reward_fig_name=network_folder+algofoler+'imgs/rewards/converge.png',
#             render =False,
#             save=True,eval_trajs=0
#             )
